# %%
from pymongo import MongoClient
from pprint import pprint
import pandas as pd
import json

# %%
mongo = MongoClient(port=27017)

# %%
db = mongo['uk_food']

# %%
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
establishments= db['establishments']

# %%
query = {'scores.Hygiene': 20}


print(f" Number of documents in result: {establishments.count_documents(query)}")


results = establishments.find(query)

print('\n First Result:')
pprint(results[0])
# Out:
#  Number of documents in result: 41
#
#  First Result:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 2,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6501c5e148927525313e17ad'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
# ...

# %%
query = {'scores.Hygiene': 20}
results = establishments.find(query)

hygiene20 = pd.DataFrame(results) 


print(f"Rows in DataFrame: {len(hygiene20)}")


hygiene20.head(10)
# Out:
# Rows in DataFrame: 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  6501c5e148927525313e17ad   110681                  0
# 1  6501c5e148927525313e1b2b   612039                  0
# 2  6501c5e148927525313e1e38   730933                  0
# 3  6501c5e148927525313e2027   172735                  0
# 4  6501c5e148927525313e2035   172953                  0
# 5  6501c5e148927525313e29d2   512854                  0
# 6  6501c5e148927525313e2bf5  1537089                  0
# 7  6501c5e248927525313e411e   155648                  0
# 8  6501c5e248927525313e4561  1012883                  0
# 9  6501c5e248927525313e4d74   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...

# %%
query = {'LocalAuthorityName': {'$regex': 'London'}, 'RatingValue': {'$gte': 4 }}


print(f" Number of documents in result: {establishments.count_documents(query)}")


results = establishments.find(query)

print('\n First Result:')
pprint(results[0])
# Out:
#  Number of documents in result: 5
#
#  First Result:
# {'AddressLine1': 'Air side London City Airport',
#  'AddressLine2': 'London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Brick Lane Brews',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4649.1734848484375,
#  'FHRSID': 878523,
#  'LocalAuthorityBusinessID': 'PI/000029844',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E16 2PX',
#  'RatingDate': '2019-01-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6501c5e248927525313e7a17'),
#  'geocode': {'latitude': 51.503733, 'longitude': 0.048006},
# ...

# %%
query = {'LocalAuthorityName': {'$regex': 'London'}, 'RatingValue': {'$gte': 4 }}
results = establishments.find(query)
london4= pd.DataFrame(results)


print(f"Rows in DataFrame: {len(london4)}")


london4.head(10)
# Out:
# Rows in DataFrame: 5
#                         _id   FHRSID  ChangesByServerID  \
# 0  6501c5e248927525313e7a17   878523                  0
# 1  6501c5e248927525313e7a1a   902473                  0
# 2  6501c5e348927525313e82fa  1090021                  0
# 3  6501c5e348927525313e82fd  1090018                  0
# 4  6501c5e348927525313e8300  1090025                  0
#
#   LocalAuthorityBusinessID          BusinessName             BusinessType  \
# 0             PI/000029844      Brick Lane Brews  Restaurant/Cafe/Canteen
# 1             PI/000029852         Pret A Manger   Takeaway/sandwich shop
# 2             PI/000033477    MV Monsoon clipper  Other catering premises
# 3             PI/000033473    MV Mercury clipper  Other catering premises
# 4             PI/000033481  MV Hurricane clipper  Other catering premises
#
#    BusinessTypeID                                    AddressLine1  \
# 0               1                    Air side London City Airport
# ...

# %%
degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

query = {
    'RatingValue': 5,
    'geocode.latitude':{
        '$gte': latitude-degree_search,
        '$lte': latitude+degree_search
    },
    'geocode.longitude': {
        '$gte': longitude-degree_search,
        '$lte': longitude+degree_search
    }
}
sort = [('score.Hygiene',1)] #ascending order
limit = 5

# Print the results
pprint(list(establishments.find(query).sort(sort). limit(limit)))
# Out:
# [{'AddressLine1': 'The Old Mill 1 Old Mill Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Crab and Crayfish',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'ChangesByServerID': 0,
#   'Distance': 4647.050320500107,
#   'FHRSID': 1516619,
#   'LocalAuthorityBusinessID': '15218',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1QG',
#   'RatingDate': '1901-01-01T00:00:00',
#   'RatingKey': 'fhrs_awaitinginspection_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6501c5e248927525313e70db'),
#   'geocode': {'latitude': 51.4817109, 'longitude': 0.0840959},
# ...

# %%
results = establishments.find(query).sort(sort). limit(limit)
NearPenang = pd.DataFrame(results)
NearPenang
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  6501c5e248927525313e70db  1516619                  0
# 1  6501c5e248927525313e7139  1043513                  0
# 2  6501c5e248927525313e703f  1369377                  0
# 3  6501c5e248927525313e6fff  1489059                  0
# 4  6501c5e248927525313e7046  1497299                  0
#
#   LocalAuthorityBusinessID          BusinessName             BusinessType  \
# 0                    15218     Crab and Crayfish           Mobile caterer
# 1             PI/000205731     Ebute Metta Joint  Restaurant/Cafe/Canteen
# 2                    14345  London Grocery Store        Retailers - other
# 3                    15077  Kingsmeat Smokehouse  Other catering premises
# 4                    15139              BakeYard  Restaurant/Cafe/Canteen
#
#    BusinessTypeID                  AddressLine1 AddressLine2 AddressLine3  \
# 0            7846  The Old Mill 1 Old Mill Road                 Plumstead
# ...

# %%
pipeline = [
    {'$match': {'scores.Hygiene':0}},
    {
        '$group':
        {
            '_id': '$LocalAuthorityName', 'count': {'$sum': 1}
        }
    },
    {'$sort': {'count': -1}}
] 

results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print(f" Number of documents in result: {len(results)}")

# Print the first 10 results
pprint(results[0:10])
# Out:
#  Number of documents in result: 55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
results_df = pd.DataFrame(results)

print(f"Number of rows in DataFrame {len(results)}")


results_df = results_df.rename(columns= {'_id': "Local Authority"})

results_df.head(10)
# Out:
# Number of rows in DataFrame 55
#    Local Authority  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
